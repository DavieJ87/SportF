# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests


# Load team data
teams_url = "https://api.sportsdata.io/v3/nba/scores/json/AllTeams?key=5645f455847b4bf4a2f4c5a82c6e479b"
teams_data = requests.get(teams_url).json()

# Convert to DataFrame
teams_df = pd.DataFrame(teams_data)


# Display the first few rows of the data
teams_df.head()

# Summary statistics
teams_df.describe()

# Visualize data distribution
plt.figure(figsize=(10, 6))
sns.histplot(teams_df['Wins'], bins=20)
plt.title("Distribution of Wins")
plt.show()
# Out:
# KeyboardInterrupt
